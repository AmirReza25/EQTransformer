# %% [markdown]
# # (IV) Model Building
# You can also train the neural network on your data and build and test your own model using the following modules.

# %% [markdown]
# ### 1) Training:

# %% [markdown]
# You can build your own EQTransformer with varying encoder sizes and train it using your own data. Your data should be in the same format as our sample data.

# %%
from EQTransformer.core.trainer import trainer
trainer(input_hdf5='../ModelsAndSampleData/100samples.hdf5',
        input_csv='../ModelsAndSampleData/100samples.csv',
        output_name='test_trainer',                
        cnn_blocks=2,
        lstm_blocks=1,
        padding='same',
        activation='relu',
        drop_rate=0.2,
        label_type='gaussian',
        add_event_r=0.6,
        add_gap_r=0.2,
        shift_event_r=0.9,
        add_noise_r=0.5, 
        mode='generator',
        train_valid_test_split=[0.60, 0.20, 0.20],
        batch_size=20,
        epochs=10, 
        patience=2)
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 6000, 3)]    0
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 6000, 8)      272         input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 3000, 8)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 3000, 16)     1168        max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 1500, 16)     0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 1500, 16)     1808        max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 750, 16)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 750, 32)      3616        max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 375, 32)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 375, 32)      5152        max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 188, 32)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 188, 64)      10304       max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 94, 64)       0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 94, 64)       12352       max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 47, 64)       0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 47, 64)       256         max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 47, 64)       0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 47, 64)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 47, 64)       256         conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 47, 64)       0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 47, 64)       0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 47, 64)       0           max_pooling1d_13[0][0]
#                                                                  conv1d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 47, 64)       256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 47, 64)       0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 47, 64)       0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 47, 64)       256         conv1d_42[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 47, 64)       0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 47, 64)       0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 47, 64)       0           add_6[0][0]
#                                                                  conv1d_43[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 47, 32)       10368       add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 47, 16)       528         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 47, 16)       64          conv1d_44[0][0]
# __________________________________________________________________________________________________
# attentionD0 (SeqSelfAttention)  [(None, 47, 16), (No 1089        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 47, 16)       0           batch_normalization_9[0][0]
#                                                                  attentionD0[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 47, 16)       32          add_8[0][0]
# __________________________________________________________________________________________________
# feed_forward_2 (FeedForward)    (None, 47, 16)       4240        layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 47, 16)       0           layer_normalization_4[0][0]
#                                                                  feed_forward_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 47, 16)       32          add_9[0][0]
# __________________________________________________________________________________________________
# attentionD (SeqSelfAttention)   [(None, 47, 16), (No 1089        layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 47, 16)       0           layer_normalization_5[0][0]
#                                                                  attentionD[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 47, 16)       32          add_10[0][0]
# __________________________________________________________________________________________________
# feed_forward_3 (FeedForward)    (None, 47, 16)       4240        layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 47, 16)       0           layer_normalization_6[0][0]
#                                                                  feed_forward_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 47, 16)       32          add_11[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 47, 16)       2112        layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 47, 16)       2112        layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# attentionP (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_4[0][0]
# __________________________________________________________________________________________________
# attentionS (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_5[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_21 (UpSampling1D) (None, 94, 16)       0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_28 (UpSampling1D) (None, 94, 16)       0           attentionP[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_35 (UpSampling1D) (None, 94, 16)       0           attentionS[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_22 (UpSampling1D) (None, 188, 64)      0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_29 (UpSampling1D) (None, 188, 64)      0           conv1d_52[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_36 (UpSampling1D) (None, 188, 64)      0           conv1d_59[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_23 (UpSampling1D) (None, 376, 64)      0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_30 (UpSampling1D) (None, 376, 64)      0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_37 (UpSampling1D) (None, 376, 64)      0           conv1d_60[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_37[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_24 (UpSampling1D) (None, 752, 32)      0           conv1d_47[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_31 (UpSampling1D) (None, 752, 32)      0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_38 (UpSampling1D) (None, 752, 32)      0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# cropping1d_3 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_24[0][0]
# __________________________________________________________________________________________________
# cropping1d_4 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_31[0][0]
# __________________________________________________________________________________________________
# cropping1d_5 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 750, 32)      7200        cropping1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 750, 32)      7200        cropping1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 750, 32)      7200        cropping1d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_25 (UpSampling1D) (None, 1500, 32)     0           conv1d_48[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_32 (UpSampling1D) (None, 1500, 32)     0           conv1d_55[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_39 (UpSampling1D) (None, 1500, 32)     0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_26 (UpSampling1D) (None, 3000, 16)     0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_33 (UpSampling1D) (None, 3000, 16)     0           conv1d_56[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_40 (UpSampling1D) (None, 3000, 16)     0           conv1d_63[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_27 (UpSampling1D) (None, 6000, 16)     0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_34 (UpSampling1D) (None, 6000, 16)     0           conv1d_57[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_41 (UpSampling1D) (None, 6000, 16)     0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_41[0][0]
# __________________________________________________________________________________________________
# detector (Conv1D)               (None, 6000, 1)      89          conv1d_51[0][0]
# __________________________________________________________________________________________________
# picker_P (Conv1D)               (None, 6000, 1)      89          conv1d_58[0][0]
# __________________________________________________________________________________________________
# picker_S (Conv1D)               (None, 6000, 1)      89          conv1d_65[0][0]
# ==================================================================================================
# Total params: 258,983
# Trainable params: 258,439
# Non-trainable params: 544
# __________________________________________________________________________________________________
# Started training in generator mode ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 from EQTransformer.core.trainer import trainer
# ----> 2 trainer(input_hdf5='../ModelsAndSampleData/100samples.hdf5',
#       3         input_csv='../ModelsAndSampleData/100samples.csv',
#       4         output_name='test_trainer',
#       5         cnn_blocks=2,
#       6         lstm_blocks=1,
#       7         padding='same',
#       8         activation='relu',
#       9         drop_rate=0.2,
#      10         label_type='gaussian',
#      11         add_event_r=0.6,
#      12         add_gap_r=0.2,
#      13         shift_event_r=0.9,
#      14         add_noise_r=0.5,
#      15         mode='generator',
#      16         train_valid_test_split=[0.60, 0.20, 0.20],
#      17         batch_size=20,
#      18         epochs=10,
#      19         patience=2)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/EQTransformer-0.1.61-py3.9.egg/EQTransformer/core/trainer.py:355, in trainer(input_hdf5, input_csv, output_name, input_dimention, cnn_blocks, lstm_blocks, padding, activation, drop_rate, shuffle, label_type, normalization_mode, augmentation, add_event_r, shift_event_r, add_noise_r, drop_channel_r, add_gap_r, coda_ratio, scale_amplitude_r, pre_emphasis, loss_weights, loss_types, train_valid_test_split, mode, batch_size, epochs, monitor, patience, gpuid, gpu_limit, use_multiprocessing)
#     351     end_training = time.time()
#     353     return history, model, start_training, end_training, save_dir, save_models, len(training), len(validation)
# --> 355 history, model, start_training, end_training, save_dir, save_models, training_size, validation_size=train(args)
#     356 _document_training(history, model, start_training, end_training, save_dir, save_models, training_size, validation_size, args)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/EQTransformer-0.1.61-py3.9.egg/EQTransformer/core/trainer.py:317, in trainer.<locals>.train(args)
#     314     validation_generator = DataGenerator(validation, **params_validation)
#     316     print('Started training in generator mode ...')
# --> 317     history = model.fit_generator(generator=training_generator,
#     318                                   validation_data=validation_generator,
#     319                                   use_multiprocessing=args['use_multiprocessing'],
#     320                                   workers=multiprocessing.cpu_count(),
#     321                                   callbacks=callbacks,
#     322                                   epochs=args['epochs'],
#     323                                   class_weight={0: 0.11, 1: 0.89})
#     325 elif args['mode'] == 'preload':
#     326     X, y1, y2, y3 = data_reader(list_IDs=training+validation,
#     327                                file_name=str(args['input_hdf5']),
#     328                                dim=args['input_dimention'][0],
#    (...)
#     338                                scale_amplitude_r=args['scale_amplitude_r'],
#     339                                pre_emphasis=args['pre_emphasis'])
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1943, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1934 """Fits the model on data yielded batch-by-batch by a Python generator.
#    1935
#    1936 DEPRECATED:
#    1937   `Model.fit` now supports generators, so there is no longer any need to use
#    1938   this endpoint.
#    1939 """
#    1940 warnings.warn('`Model.fit_generator` is deprecated and '
#    1941               'will be removed in a future version. '
#    1942               'Please use `Model.fit`, which supports generators.')
# -> 1943 return self.fit(
#    1944     generator,
#    1945     steps_per_epoch=steps_per_epoch,
#    1946     epochs=epochs,
#    1947     verbose=verbose,
#    1948     callbacks=callbacks,
#    1949     validation_data=validation_data,
#    1950     validation_steps=validation_steps,
#    1951     validation_freq=validation_freq,
#    1952     class_weight=class_weight,
#    1953     max_queue_size=max_queue_size,
#    1954     workers=workers,
#    1955     use_multiprocessing=use_multiprocessing,
#    1956     shuffle=shuffle,
#    1957     initial_epoch=initial_epoch)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1133, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1127   self._cluster_coordinator = cluster_coordinator.ClusterCoordinator(
#    1128       self.distribute_strategy)
#    1130 with self.distribute_strategy.scope(), \
#    1131      training_utils.RespectCompiledTrainableState(self):
#    1132   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1133   data_handler = data_adapter.get_data_handler(
#    1134       x=x,
#    1135       y=y,
#    1136       sample_weight=sample_weight,
#    1137       batch_size=batch_size,
#    1138       steps_per_epoch=steps_per_epoch,
#    1139       initial_epoch=initial_epoch,
#    1140       epochs=epochs,
#    1141       shuffle=shuffle,
#    1142       class_weight=class_weight,
#    1143       max_queue_size=max_queue_size,
#    1144       workers=workers,
#    1145       use_multiprocessing=use_multiprocessing,
#    1146       model=self,
#    1147       steps_per_execution=self._steps_per_execution)
#    1149   # Container that configures and calls `tf.keras.Callback`s.
#    1150   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/data_adapter.py:1364, in get_data_handler(*args, **kwargs)
#    1362 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1363   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1364 return DataHandler(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/data_adapter.py:1174, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1171 self._step_increment = self._steps_per_execution_value - 1
#    1172 self._insufficient_data = False
# -> 1174 self._configure_dataset_and_inferred_steps(strategy, x, steps_per_epoch,
#    1175                                            class_weight, distribute)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/data_adapter.py:1186, in DataHandler._configure_dataset_and_inferred_steps(***failed resolving arguments***)
#    1184 dataset = self._adapter.get_dataset()
#    1185 if class_weight:
# -> 1186   dataset = dataset.map(_make_class_weight_map_fn(class_weight))
#    1187 self._inferred_steps = self._infer_steps(steps_per_epoch, dataset)
#    1189 # `PreprocessingLayer.adapt` does not currently support distributed
#    1190 # datasets, so we pass `distribute=False` there.
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:1925, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic)
#    1922   if deterministic is not None and not DEBUG_MODE:
#    1923     warnings.warn("The `deterministic` argument has no effect unless the "
#    1924                   "`num_parallel_calls` argument is specified.")
# -> 1925   return MapDataset(self, map_func, preserve_cardinality=True)
#    1926 else:
#    1927   return ParallelMapDataset(
#    1928       self,
#    1929       map_func,
#    1930       num_parallel_calls,
#    1931       deterministic,
#    1932       preserve_cardinality=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:4483, in MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    4481 self._use_inter_op_parallelism = use_inter_op_parallelism
#    4482 self._preserve_cardinality = preserve_cardinality
# -> 4483 self._map_func = StructuredFunctionWrapper(
#    4484     map_func,
#    4485     self._transformation_name(),
#    4486     dataset=input_dataset,
#    4487     use_legacy_function=use_legacy_function)
#    4488 variant_tensor = gen_dataset_ops.map_dataset(
#    4489     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    4490     self._map_func.function.captured_inputs,
#    (...)
#    4493     preserve_cardinality=self._preserve_cardinality,
#    4494     **self._flat_structure)
#    4495 super(MapDataset, self).__init__(input_dataset, variant_tensor)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3712, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3710 resource_tracker = tracking.ResourceTracker()
#    3711 with tracking.resource_tracker_scope(resource_tracker):
# -> 3712   self._function = fn_factory()
#    3713   # There is no graph to add in eager mode.
#    3714   add_to_graph &= not context.executing_eagerly()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3134, in Function.get_concrete_function(self, *args, **kwargs)
#    3125 def get_concrete_function(self, *args, **kwargs):
#    3126   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    3127
#    3128   Args:
#    (...)
#    3132        or `tf.Tensor` or `tf.TensorSpec`.
#    3133   """
# -> 3134   graph_function = self._get_concrete_function_garbage_collected(
#    3135       *args, **kwargs)
#    3136   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3137   return graph_function
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3100, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3098   args, kwargs = None, None
#    3099 with self._lock:
# -> 3100   graph_function, _ = self._maybe_define_function(args, kwargs)
#    3101   seen_names = set()
#    3102   captured = object_identity.ObjectIdentitySet(
#    3103       graph_function.graph.internal_captures)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3444, in Function._maybe_define_function(self, args, kwargs)
#    3440   return self._define_function_with_shape_relaxation(
#    3441       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3443 self._function_cache.missed.add(call_context_key)
# -> 3444 graph_function = self._create_graph_function(args, kwargs)
#    3445 self._function_cache.primary[cache_key] = graph_function
#    3447 return graph_function, filtered_flat_args
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3279, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3274 missing_arg_names = [
#    3275     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3276 ]
#    3277 arg_names = base_arg_names + missing_arg_names
#    3278 graph_function = ConcreteFunction(
# -> 3279     func_graph_module.func_graph_from_py_func(
#    3280         self._name,
#    3281         self._python_function,
#    3282         args,
#    3283         kwargs,
#    3284         self.input_signature,
#    3285         autograph=self._autograph,
#    3286         autograph_options=self._autograph_options,
#    3287         arg_names=arg_names,
#    3288         override_flat_arg_shapes=override_flat_arg_shapes,
#    3289         capture_by_value=self._capture_by_value),
#    3290     self._function_attributes,
#    3291     function_spec=self.function_spec,
#    3292     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3293     # scope. This is not the default behavior since it gets used in some
#    3294     # places (like Keras) where the FuncGraph lives longer than the
#    3295     # ConcreteFunction.
#    3296     shared_func_graph=False)
#    3297 return graph_function
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py:999, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     996 else:
#     997   _, original_func = tf_decorator.unwrap(python_func)
# --> 999 func_outputs = python_func(*func_args, **func_kwargs)
#    1001 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1002 # TensorArrays and `None`s.
#    1003 func_outputs = nest.map_structure(convert, func_outputs,
#    1004                                   expand_composites=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3687, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#    3681 @eager_function.defun_with_attributes(
#    3682     input_signature=structure.get_flat_tensor_specs(
#    3683         self._input_structure),
#    3684     autograph=False,
#    3685     attributes=defun_kwargs)
#    3686 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> 3687   ret = wrapper_helper(*args)
#    3688   ret = structure.to_tensor_list(self._output_structure, ret)
#    3689   return [ops.convert_to_tensor(t) for t in ret]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3617, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#    3615 if not _should_unpack(nested_args):
#    3616   nested_args = (nested_args,)
# -> 3617 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    3618 if _should_pack(ret):
#    3619   ret = tuple(ret)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:692, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     690 try:
#     691   with conversion_ctx:
# --> 692     return converted_call(f, args, kwargs, options=options)
#     693 except Exception as e:  # pylint:disable=broad-except
#     694   if hasattr(e, 'ag_error_metadata'):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:382, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     379   return _call_unconverted(f, args, kwargs, options)
#     381 if not options.user_requested and conversion.is_allowlisted(f):
# --> 382   return _call_unconverted(f, args, kwargs, options)
#     384 # internal_convert_user_code is for example turned off when issuing a dynamic
#     385 # call conversion from generated code while in nonrecursive mode. In that
#     386 # case we evidently don't want to recurse, but we still have to convert
#     387 # things like builtins.
#     388 if not options.internal_convert_user_code:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:463, in _call_unconverted(f, args, kwargs, options, update_cache)
#     460   return f.__self__.call(args, kwargs)
#     462 if kwargs is not None:
# --> 463   return f(*args, **kwargs)
#     464 return f(*args)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/data_adapter.py:1397, in _make_class_weight_map_fn.<locals>._class_weights_map_fn(*data)
#    1394 x, y, sw = unpack_x_y_sample_weight(data)
#    1396 if nest.is_nested(y):
# -> 1397   raise ValueError(
#    1398       "`class_weight` is only supported for Models with a single output.")
#    1400 if y.shape.rank > 2:
#    1401   raise ValueError("`class_weight` not supported for "
#    1402                    "3+ dimensional targets.")
#
# ValueError: `class_weight` is only supported for Models with a single output.

# %% [markdown]
# ### 2) Test Your Model:

# %% [markdown]
# You can then test the model you just trained based on the ground truth labels:

# %%
from EQTransformer.core.tester import tester
tester(input_hdf5='../ModelsAndSampleData/100samples.hdf5',
       input_testset='test_trainer_outputs/test.npy',
       input_model='test_trainer_outputs/models/test_trainer_001.h5',
       output_name='test_tester',
       detection_threshold=0.20,                
       P_threshold=0.1,
       S_threshold=0.1, 
       number_of_plots=3,
       estimate_uncertainty=True, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)
# Out:
# Loading the model ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 2
#       1 from EQTransformer.core.tester import tester
# ----> 2 tester(input_hdf5='../ModelsAndSampleData/100samples.hdf5',
#       3        input_testset='test_trainer_outputs/test.npy',
#       4        input_model='test_trainer_outputs/models/test_trainer_001.h5',
#       5        output_name='test_tester',
#       6        detection_threshold=0.20,
#       7        P_threshold=0.1,
#       8        S_threshold=0.1,
#       9        number_of_plots=3,
#      10        estimate_uncertainty=True,
#      11        number_of_sampling=2,
#      12        input_dimention=(6000, 3),
#      13        normalization_mode='std',
#      14        mode='generator',
#      15        batch_size=10,
#      16        gpuid=None,
#      17        gpu_limit=None)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/EQTransformer-0.1.61-py3.9.egg/EQTransformer/core/tester.py:177, in tester(input_hdf5, input_testset, input_model, output_name, detection_threshold, P_threshold, S_threshold, number_of_plots, estimate_uncertainty, number_of_sampling, loss_weights, loss_types, input_dimention, normalization_mode, mode, batch_size, gpuid, gpu_limit)
#     174 test = np.load(args['input_testset'])
#     176 print('Loading the model ...', flush=True)
# --> 177 model = load_model(args['input_model'], custom_objects={'SeqSelfAttention': SeqSelfAttention,
#     178                                                      'FeedForward': FeedForward,
#     179                                                      'LayerNormalization': LayerNormalization,
#     180                                                      'f1': f1
#     181                                                      })
#     183 model.compile(loss = args['loss_types'],
#     184               loss_weights =  args['loss_weights'],
#     185               optimizer = Adam(lr = 0.001),
#     186               metrics = [f1])
#     188 print('Loading is complete!', flush=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/saving/save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204       filepath = path_to_string(filepath)
#     205       if isinstance(filepath, str):
# --> 206         return saved_model_load.load(filepath, compile, options)
#     208 raise IOError(
#     209     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     210     'available) or SavedModel.')
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/saving/saved_model/load.py:121, in load(path, compile, options)
#     116 # TODO(kathywu): Add saving/loading of optimizer, compiled losses and metrics.
#     117 # TODO(kathywu): Add code to load from objects that contain all endpoints
#     118
#     119 # Look for metadata file or parse the SavedModel
#     120 metadata = saved_metadata_pb2.SavedMetadata()
# --> 121 meta_graph_def = loader_impl.parse_saved_model(path).meta_graphs[0]
#     122 object_graph_def = meta_graph_def.object_graph_def
#     123 path_to_metadata_pb = os.path.join(path, constants.SAVED_METADATA_PATH)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/saved_model/loader_impl.py:113, in parse_saved_model(export_dir)
#     111     raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     112 else:
# --> 113   raise IOError(
#     114       "SavedModel file does not exist at: %s%s{%s|%s}" %
#     115       (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
#     116        constants.SAVED_MODEL_FILENAME_PB))
#
# OSError: SavedModel file does not exist at: test_trainer_outputs/models/test_trainer_001.h5/{saved_model.pbtxt|saved_model.pb}
